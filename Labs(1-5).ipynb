# %% [markdown]
# <b>Lab 1: <b><br>
# Завдання: познайомитися із роботою найпростіших операцій із зображенням <br>
# path = r"E:/KHPI/Computer Vision/Lab(1-5)/pics/12.jpg"
#
# ![12.jpg](attachment:dff21702-4fde-4bc8-9adc-03fe407f488d.jpg)

# %% [markdown]
# <b>Program code:<b>

# %%
import cv2
picture = cv2.imread(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/12.jpg")
cv2.imshow("Initial picture", picture)
cv2.waitKey(-1);
cv2.destroyAllWindows()

def Visualization(picture, x):
    cv2.namedWindow(x, cv2.WINDOW_NORMAL)
    cv2.imshow(x, picture)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
Visualization(picture [15:480, 80:680], "Cutted picture")
pict = cv2.imread(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/12.jpg")

d = (int(pict.shape[1] * 40 / 100), int(pict.shape[0] * 40 / 100))

Visualization(cv2.resize(pict, d, interpolation = cv2.INTER_AREA), "At scale - 40%")

h, w, d = pict.shape
c = (w // 2, h // 2)

Visualization(cv2.warpAffine(pict, cv2.getRotationMatrix2D (c, 45, 1), (w, h)),"Rotate at 45 degree")
new_picture = pict.copy()

cv2.line(new_picture, (0, 0), (900, 900), (0, 100, 255), 10) #cv2.line(image, start_point, end_point, color, thickness) 

Visualization(new_picture, "Line drawn")

new_picture = pict.copy()

new_picture = cv2.putText(
    img=new_picture,  # Specify the target image
    text="Good afternoon we are from Ukraine",
    org=(10, 200),
    fontFace=cv2.FONT_HERSHEY_DUPLEX,
    fontScale=3.0,
    color=(100, 206, 55),
    thickness=3
)
Visualization(new_picture, "Text message")

# %% [markdown]
# <b>Lab 2: Зчитування, виведення на екран та запис зображення. <b><br>
# path = r"E:/KHPI/Computer Vision/Lab(1-5)/pics/12.jpg"
# ![12.jpg](attachment:e7928344-b39e-4e3e-adc2-2c73a476fd96.jpg)

# %% [markdown]
# <b>Program code<b>

# %% [markdown]
#     Task №1:
#     Зчитати повнокольорове зображення 12.jpg, створити йому матрицю зображення, потім вивести спочатку напівтонове, потім кольорове зображення на екран. Перед виконанням завдання отримати згідно з номером у списку групи свій файл з зображенням.

# %%
import cv2
import numpy as np
import os
import random as r

def Visualization(picture, name):
    cv2.namedWindow(name, cv2.WINDOW_NORMAL)
    cv2.imshow(name, picture)


def colorSelection(img, flag):
    
    if flag == 0:
        Visualization(cv2.resize(img, (int(img.shape[1] * 40 / 100), int(img.shape[0] * 40 / 100)), interpolation = cv2.INTER_AREA), "Initial picture")
        #writeToFile(img)
        
    if flag == 1:
        Visualization(cv2.resize(img, (int(img.shape[1] * 40 / 100), int(img.shape[0] * 40 / 100)), interpolation = cv2.INTER_AREA), "Grayscale")
        #writeToFile(img)

#useless        
def writeToFile(img, path = r"E:/KHPI/Computer Vision/Lab(1-5)/pics/"):
    os.chdir(path)
    filename = "matrix" + str(r.randint(1, 10)) + ".jpg"
    cv2.imwrite(filename, img)
    print("Succeeded" + " " + filename)
    print(os.listdir(path))
    

img1 = cv2.imread(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/12.jpg", 1)
img2 = cv2.imread(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/12.jpg", 0)

def main():
    colorSelection(img1, 0)
    colorSelection(img2, 1)
    

main()

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# <b>Task №2:<b><br>
# Сформувати матрицю зображення, записати її в файл. Після виконання коду перевірити, чи з'явився новий файл на диску.

# %%
import cv2
import os

path = r"E:/KHPI/Computer Vision/Lab(1-5)/pics/"
os.chdir(path)
filename = "12.jpg"

# Load the image with the full path
image = cv2.imread(os.path.join(path, filename), 0)

# Check if the image was loaded successfully
if image is not None:
    # Write the loaded image with the specified filename
    cv2.imwrite("blacked12.jpg", image)

    cv2.namedWindow("Initial picture", cv2.WINDOW_NORMAL)
    cv2.imshow("Initial picture", image)
    print("Succeeded")
    cv2.waitKey(-1)
    cv2.destroyAllWindows()
else:
    print("Failed to load the image.")
# Out:
# Succeeded

# %% [markdown]
# <b>Task №3:<b><br>
# Вивести властивості матриці зображення на екран.

# %%
import cv2
import numpy as np

image = cv2.imread(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/12.jpg")
image = cv2.resize(image, (int(image.shape[1] * 40 / 100), int(image.shape[0] * 40 / 100)),
                   interpolation=cv2.INTER_AREA)
cv2.imshow("Initial picture", image)
b, g, r = cv2.split(image)

print("Red color intensity  " + str(round(np.mean(r), 5)))
print("Grey color intensity " + str(round(np.mean(g), 5)))
print("Blue color intensity " + str(round(np.mean(b), 5)))
print("Image size " + str(image.size))
print("Image shape " + str(image.shape))
print("Image type " + str(image.dtype))
#cv2.imshow("ff", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Red color intensity  114.03058
# Grey color intensity 121.33813
# Blue color intensity 118.80473
# Image size 995328
# Image shape (432, 768, 3)
# Image type uint8

# %% [markdown]
# <b>Task №4: <b><br>
# Визначити за допомогою функції print (img.shape ) максимальне число пікселів за шириною та висотою зображення. Вибрати координати так, щоб вони не виходили за межі розмірів зображення. Задати координату по горизонталі рівної сумі номера за списком групи плюс 70, по вертикалі дорівнює сумі номера по списку групи плюс 50.

# %%
import cv2
import numpy as np

image = cv2.imread(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/12.jpg")
image= cv2.resize(image, (int(image.shape[1] * 40 / 100), int(image.shape[0] * 40 / 100)), interpolation=cv2.INTER_AREA)
cv2.imshow("Initial picture", image)
print(image.shape)
px = image[82,62]
print(px)

s = image[82, 62, 0]
print(s)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (432, 768, 3)
# [103 128 128]
# 103

# %% [markdown]
# Task №5 <br>
# <b>Зчитати повнокольорове зображення, створити для нього два місця у вікні завширшки і два місця у висоту.
# Перетворити матрицю кольорового зображення на напівтонове, з нього, використовуючи функцію cv2.threshold, отримати бінарне монохромне зображення. З бінарного монохромного зображення отримати його негати<b>в.

# %%
import cv2
import matplotlib.pyplot as plt

# Зчитуємо повнокольорове зображення
color_image = cv2.imread(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/12.jpg")

# Перетворимо зображення у відтінки сірого
gray_image = cv2.cvtColor(color_image, cv2.COLOR_BGR2GRAY)

# Використовуємо функцію cv2.threshold для отримання бінарного зображення
_, binary_image = cv2.threshold(gray_image, 128, 255, cv2.THRESH_BINARY)

# Отримуємо негатив бінарного зображення
negative_image = cv2.bitwise_not(binary_image)

# Виводимо зображення в одному вікні
plt.figure(figsize=(10, 8))

# Вихідне зображення
plt.subplot(221)
plt.imshow(cv2.cvtColor(color_image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis("off")

# Кольорове монохромне зображення
plt.subplot(222)
plt.imshow(gray_image, cmap='gray')
plt.title('Grayscale Image')
plt.axis("off")

# Бінарне монохромне зображення
plt.subplot(223)
plt.imshow(binary_image, cmap='gray')
plt.title('Binary Image')
plt.axis("off")

# Інвертоване зображення
plt.subplot(224)
plt.imshow(negative_image, cmap='gray')
plt.title('Negative Image')
plt.axis("off")

# Показати всі зображення
plt.show()

# %% [markdown]
# Task №6:<br>
# <b>
# На заданому зображенні виділити його характерну ділянку - номерний знак (ROI).
# <b>

# %%
import cv2

img = cv2.imread(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/12.jpg")


image = cv2.rectangle(img, (1100, 731), (1345, 644),(60,200),2)
cv2.imshow('IMG', img)
cv2.imwrite(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/Rectangled.jpg", image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# <b>Result:<br><b>
# ![Rectangled.jpg](attachment:843937d4-46e7-41bc-9b06-ee313e48e816.jpg)

# %% [markdown]
# <b>Lab №3<b><br>
# Застосування фільтрів. завантажити на одному екрані вихідне зображення, а також результати роботи вище вказаних фільтрів.

# %%
import cv2
import numpy as np

def improve_image_with_median_filter(image_for_median):
    processed_image = cv2.medianBlur(image_for_median, 7)
    cv2.imshow('Median Filter', processed_image)
    cv2.imwrite(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/Median_processed_image.png", processed_image)

def improve_image_with_mean_filter(image_for_mean):
    kernel = np.ones((5, 5), np.float32) / 25
    processed_image = cv2.filter2D(image_for_mean, -1, kernel)
    cv2.imshow('Mean Filter', processed_image)
    cv2.imwrite(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/Mean_processed_image.png", processed_image)

def improve_image_with_erode(image_for_erode):
    kernel = np.ones( (5, 5), np. uint8)
    processed_image = cv2.erode(image_for_erode, kernel, iterations=1)
    cv2.imshow("Erode Filter", processed_image)
    cv2.imwrite(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/Erode_processed_image.png", processed_image)
    
image = cv2.imread(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/12.jpg")
image = cv2.resize(image, (int(image.shape[1] * 30 / 100), int(image.shape[0] * 30 / 100)), interpolation=cv2.INTER_AREA)

cv2.imshow('Initial image', image)
improve_image_with_median_filter(image)
improve_image_with_mean_filter(image)
improve_image_with_erode(image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# <b>Resulting window:<b>

# %%
import cv2
import matplotlib.pyplot as plt

# Load the images
img_original = cv2.imread(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/12.jpg")
img_median = cv2.imread(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/Median_processed_image.png")
img_mean = cv2.imread(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/Mean_processed_image.png")
img_erode = cv2.imread(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/Erode_processed_image.png")

# Create a 2x2 grid of subplots
plt.figure(figsize=(10, 8))

# Original Image
plt.subplot(221)
plt.imshow(cv2.cvtColor(img_original, cv2.COLOR_BGR2RGB))
plt.title('Original Image')

# Median Image
plt.subplot(222)
plt.imshow(cv2.cvtColor(img_median, cv2.COLOR_BGR2RGB))
plt.title("Median Image")

# Mean Image
plt.subplot(223)
plt.imshow(cv2.cvtColor(img_mean, cv2.COLOR_BGR2RGB))
plt.title('Mean Image')

# Erode Image
plt.subplot(224)
plt.imshow(cv2.cvtColor(img_erode, cv2.COLOR_BGR2RGB))
plt.title('Erode Image')

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# <b>Lab №4<b> <br>Середньогеометричний фільтр

# %% [markdown]
# <b>Task 1<b> <br>
# Завдання: застосувати середньогеометрийчний фільтр до зашумленого зображення, вивести отримане та початкове зображення на екран та порівняти.

# %%
import cv2
import numpy as np
import random

# Define valid RGB colors within the [0, 255] range
red, green, blue = (255, 0, 0), (0, 255, 0), (0, 0, 255)
rgb = [red, green, blue]

def ap_noise(image, prob):
    output = np.zeros(image.shape, np.uint8)
    thres = 1 - prob
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            ran = random.random()
            if ran > thres:
                output[i][j] = random.choice(rgb)
            else:
                output[i][j] = image[i][j]
    return output

# Load the input image (adjust the path as needed)
image = cv2.imread(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/12.jpg")

# Resize the image
image = cv2.resize(image, (458, 308))

# Apply noise to the image
noise_img = ap_noise(image, 0.3)

# Save the noisy image to a file
cv2.imwrite(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/Noise.jpg", noise_img)

# Optionally, display the original and noisy images
cv2.imshow("Original and Noisy", np.hstack((image, noise_img)))
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# <b>Result of noisy picture at local disk<b><br>
# ![Noise.jpg](attachment:cee18c6a-0af6-490e-88e4-47451ccc3c75.jpg)

# %% [markdown]
# <b>Task 2<b><br>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def GeometricMeanAlogrithm (image):
    new_image =np.zeros(image.shape)
    image= cv2.copyMakeBorder (image,1,1,1,1,cv2.BORDER_DEFAULT)
    for i in range(1, image.shape[0] -1):
        for j in range (1, image.shape[1] - 1):
            roi = image[i-1:i+2, j-1:j+2]
            roi =roi.astype(np.float64)
            p=np.prod(roi)
            new_image[i-1, j-1]= p**(1/(roi.shape[0]*roi.shape[1]))
    return new_image.astype(np.uint8)
    
def rgbGeometricMean(image):
    r, g ,b = cv2.split(image)
    r = GeometricMeanAlogrithm(r)
    g = GeometricMeanAlogrithm(g)
    b = GeometricMeanAlogrithm(b)
    return cv2.merge([r,g,b])

img = cv2.imread(r"E:/KHPI/Computer Vision/Lab(1-5)/pics/noise.jpg")
image= cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
plt.imshow(image)
plt.title("Noisy image")
plt.show()
newimg= rgbGeometricMean(image)
plt.imshow(newimg)
plt.title("Geometric Mean Filter")
plt.show()

# %% [markdown]
# <b>Lab 5<b><br>
# Просторовий фільтр підвищення різкості. Фільтр Лапласа.

# %% [markdown]
# <b>Task:<b><br> Застосувати фільтр Лапласа до напівтонового зображення, вивести отримане та початкове зображення на екран та порівняти.

# %%
import cv2 as cv

ddepth = cv.CV_16S
kernel_size = 3
window_name = "Laplace"

window_name_original = "original"
imageName = r"E:/KHPI/Computer Vision/Lab(1-5)/pics/12.jpg"

src = cv.imread(cv.samples.findFile(imageName), cv.IMREAD_COLOR)
src= cv.resize(src, (int(src.shape[1] * 40 / 100), int(src.shape[0] * 40 / 100)), interpolation=cv.INTER_AREA)

cv.imshow(window_name_original, src)
src = cv.GaussianBlur(src, (3, 3), 0)
src_gray = cv.cvtColor(src, cv.COLOR_BGR2GRAY)
cv.namedWindow(window_name, cv.WINDOW_AUTOSIZE)
dst = cv.Laplacian(src_gray, ddepth, ksize=kernel_size)
abs_dst = cv.convertScaleAbs(dst)
cv.imshow(window_name, abs_dst)
cv.waitKey(0)
cv.destroyAllWindows()
